# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from openai import OpenAI
from key import OPENAI_API_KEY
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
movie_latest_small=pd.read_csv('../../data/processed_movie_latest_small.csv')
movie_latest_small.head()
# Out:
#    userId  movieId                        title  \
# 0       1        1             Toy Story (1995)
# 1       1        3      Grumpier Old Men (1995)
# 2       1        6                  Heat (1995)
# 3       1       47  Seven (a.k.a. Se7en) (1995)
# 4       1       50   Usual Suspects, The (1995)
#
#                                             genres  rating  timestamp  tag
# 0  Adventure, Animation, Children, Comedy, Fantasy     4.0  964982703  NaN
# 1                                  Comedy, Romance     4.0  964981247  NaN
# 2                          Action, Crime, Thriller     4.0  964982224  NaN
# 3                                Mystery, Thriller     5.0  964983815  NaN
# 4                         Crime, Mystery, Thriller     5.0  964982931  NaN

# %%
# for each user, find his top-most rated movies
N_TOP_MOVIES = 10
def get_top_recent_movies(movies_df, user_id, num_movies=N_TOP_MOVIES):
    user_ratings = movies_df[movies_df['userId'] == user_id]
    user_ratings = user_ratings.sort_values(by=['rating', 'timestamp'], ascending=[False, False])
    return user_ratings.head(num_movies)

# get the top 5 movies for all users
top_movies = pd.DataFrame()
for user_id in movie_latest_small['userId'].unique():
    top_movies = pd.concat([top_movies, get_top_recent_movies(movie_latest_small, user_id, 10)])
top_movies.reset_index(drop=True, inplace=True)
top_movies.head(15)
# Out:
#     userId  movieId                                            title  \
# 0        1      553                                 Tombstone (1993)
# 1        1      157                            Canadian Bacon (1995)
# 2        1     1298                      Pink Floyd: The Wall (1982)
# 3        1     3053  Messenger: The Story of Joan of Arc, The (1999)
# 4        1     3448                     Good Morning, Vietnam (1987)
# 5        1      151                                   Rob Roy (1995)
# 6        1     1224                                   Henry V (1989)
# 7        1      527                          Schindler's List (1993)
# 8        1     5060                     M*A*S*H (a.k.a. MASH) (1970)
# 9        1     3147                           Green Mile, The (1999)
# 10       2   122882                        Mad Max: Fury Road (2015)
# 11       2    89774                                   Warrior (2011)
# 12       2    80906                                Inside Job (2010)
# 13       2    60756                             Step Brothers (2008)
# 14       2   106782                  Wolf of Wall Street, The (2013)
#
#                                  genres  rating   timestamp  \
# 0                Action, Drama, Western     5.0   964984153
# 1                           Comedy, War     5.0   964984100
# 2                        Drama, Musical     5.0   964984086
# 3                            Drama, War     5.0   964984086
# 4                    Comedy, Drama, War     5.0   964984054
# 5           Action, Drama, Romance, War     5.0   964984041
# 6           Action, Drama, Romance, War     5.0   964984018
# 7                            Drama, War     5.0   964984002
# 8                    Comedy, Drama, War     5.0   964984002
# 9                          Crime, Drama     5.0   964983873
# 10  Action, Adventure, Sci-Fi, Thriller     5.0  1445715272
# 11                                Drama     5.0  1445715189
# 12                          Documentary     5.0  1445715172
# 13                               Comedy     5.0  1445714980
# 14                 Comedy, Crime, Drama     5.0  1445714966
#
#                                           tag
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11               Boxing story, MMA, Tom Hardy
# 12                                        NaN
# 13       funny, Highly quotable, will ferrell
# 14  drugs, Leonardo DiCaprio, Martin Scorsese

# %%
import re

def extract_movie_titles(response):
    # Extract lines that match the format [Title (Year)]
    pattern = r"\[.*\]"
    titles = re.findall(pattern, response)
    return [title.strip("[]") for title in titles]

# %%
""" Number of users to run the recommender on
    (Use a small sample for faster results)
    If you want to run the recommender on all users, uncomment the last line
"""
num_users = 5

# Uncomment below to run on all users
# num_users = len(prompts_1)

# %% [markdown]
# ## Add steps

# %%
def generate_step1_prompt(df, user_id, num_movies=N_TOP_MOVIES):
    df_user = df[df['userId'] == user_id]
    movies_list = '\n'.join([f"Movie {i+1}: {row['title']}, Genre: {row['genres']}, Rating: {row['rating']}" for i, row in df_user.iterrows()])
    
    prompt_template = '''
I am user {user_id}. My most recent {num} top-rated movies are listed below along with their genres and ratings:
{movies_list}
Step 1: What are my key preferences when selecting movies?
Answer:
    '''

    prompt = prompt_template.format(user_id=user_id, num=num_movies, movies_list=movies_list)
    return prompt

def generate_step2_prompt(df, user_id, response1,num_movies=N_TOP_MOVIES):
    df_user = df[df['userId'] == user_id]
    movies_list = '\n'.join([f"Movie {i+1}: {row['title']}, Genre: {row['genres']}, Rating: {row['rating']}" for i, row in df_user.iterrows()])
    
    prompt_template = '''
I am user {user_id}. My most recent {num} top-rated movies are listed below along with their genres and ratings:
{movies_list}
Step 1: What are my key preferences when selecting movies?
Answer: {response1}
Step 2: Based on my preference, please recommend 10 movies similar to these that I haven't watched yet. Format your response as a list of movie titles, using brackets around the titles and separating each title with a new line for easy parsing.
Example format:
Here are the 10 movies recommended for you: 
[Midnight Cowboy (1969)]
[Lost in Translation (2003)]
[etc.]

Answer:
    '''

    prompt = prompt_template.format(user_id=user_id, num=num_movies, movies_list=movies_list, response1=response1)
    return prompt

# %%
prompts_1step = []
prompts_2step = []

for user_id in top_movies['userId'].unique()[:num_users]:
    prompt = generate_step1_prompt(top_movies, user_id)
    prompts_1step.append(prompt)

prompts_1step
# Out:
# ["\nI am user 1. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 1: Tombstone (1993), Genre: Action, Drama, Western, Rating: 5.0\nMovie 2: Canadian Bacon (1995), Genre: Comedy, War, Rating: 5.0\nMovie 3: Pink Floyd: The Wall (1982), Genre: Drama, Musical, Rating: 5.0\nMovie 4: Messenger: The Story of Joan of Arc, The (1999), Genre: Drama, War, Rating: 5.0\nMovie 5: Good Morning, Vietnam (1987), Genre: Comedy, Drama, War, Rating: 5.0\nMovie 6: Rob Roy (1995), Genre: Action, Drama, Romance, War, Rating: 5.0\nMovie 7: Henry V (1989), Genre: Action, Drama, Romance, War, Rating: 5.0\nMovie 8: Schindler's List (1993), Genre: Drama, War, Rating: 5.0\nMovie 9: M*A*S*H (a.k.a. MASH) (1970), Genre: Comedy, Drama, War, Rating: 5.0\nMovie 10: Green Mile, The (1999), Genre: Crime, Drama, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer:\n    ",
#  '\nI am user 2. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 11: Mad Max: Fury Road (2015), Genre: Action, Adventure, Sci-Fi, Thriller, Rating: 5.0\nMovie 12: Warrior (2011), Genre: Drama, Rating: 5.0\nMovie 13: Inside Job (2010), Genre: Documentary, Rating: 5.0\nMovie 14: Step Brothers (2008), Genre: Comedy, Rating: 5.0\nMovie 15: Wolf of Wall Street, The (2013), Genre: Comedy, Crime, Drama, Rating: 5.0\nMovie 16: The Jinx: The Life and Deaths of Robert Durst (2015), Genre: Documentary, Rating: 5.0\nMovie 17: Town, The (2010), Genre: Crime, Drama, Thriller, Rating: 4.5\nMovie 18: Good Will Hunting (1997), Genre: Drama, Romance, Rating: 4.5\nMovie 19: Inglourious Basterds (2009), Genre: Action, Drama, War, Rating: 4.5\nMovie 20: Dark Knight, The (2008), Genre: Action, Crime, Drama, IMAX, Rating: 4.5\nStep 1: What are my key preferences when selecting movies?\nAnswer:\n    ',
#  '\nI am user 3. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 21: Saturn 3 (1980), Genre: Adventure, Sci-Fi, Thriller, Rating: 5.0\nMovie 22: Android (1982), Genre: Sci-Fi, Rating: 5.0\nMovie 23: Troll 2 (1990), Genre: Fantasy, Horror, Rating: 5.0\nMovie 24: The Lair of the White Worm (1988), Genre: Comedy, Horror, Rating: 5.0\nMovie 25: Hangar 18 (1980), Genre: Action, Sci-Fi, Thriller, Rating: 5.0\nMovie 26: Galaxy of Terror (Quest) (1981), Genre: Action, Horror, Mystery, Sci-Fi, Rating: 5.0\nMovie 27: Death Race 2000 (1975), Genre: Action, Sci-Fi, Rating: 5.0\nMovie 28: Alien Contamination (1980), Genre: Action, Horror, Sci-Fi, Rating: 5.0\nMovie 29: Escape from L.A. (1996), Genre: Action, Adventure, Sci-Fi, Thriller, Rating: 5.0\nMovie 30: Road Warrior, The (Mad Max 2) (1981), Genre: Action, Adventure, Sci-Fi, Thriller, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer:\n    ',
#  "\nI am user 4. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 31: L.I.E. (2001), Genre: Drama, Rating: 5.0\nMovie 32: No Man's Land (2001), Genre: Drama, War, Rating: 5.0\nMovie 33: Hairspray (1988), Genre: Comedy, Drama, Rating: 5.0\nMovie 34: Gods Must Be Crazy, The (1980), Genre: Adventure, Comedy, Rating: 5.0\nMovie 35: Monty Python's Life of Brian (1979), Genre: Comedy, Rating: 5.0\nMovie 36: Monty Python and the Holy Grail (1975), Genre: Adventure, Comedy, Fantasy, Rating: 5.0\nMovie 37: I'm the One That I Want (2000), Genre: Comedy, Rating: 5.0\nMovie 38: Traffic (2000), Genre: Crime, Drama, Thriller, Rating: 5.0\nMovie 39: Blow (2001), Genre: Crime, Drama, Rating: 5.0\nMovie 40: Philadelphia Story, The (1940), Genre: Comedy, Drama, Romance, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer:\n    ",
#  "\nI am user 5. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 41: Heavenly Creatures (1994), Genre: Crime, Drama, Rating: 5.0\nMovie 42: Once Were Warriors (1994), Genre: Crime, Drama, Rating: 5.0\nMovie 43: In the Name of the Father (1993), Genre: Drama, Rating: 5.0\nMovie 44: Pinocchio (1940), Genre: Animation, Children, Fantasy, Musical, Rating: 5.0\nMovie 45: Postman, The (Postino, Il) (1994), Genre: Comedy, Drama, Romance, Rating: 5.0\nMovie 46: Snow White and the Seven Dwarfs (1937), Genre: Animation, Children, Drama, Fantasy, Musical, Rating: 5.0\nMovie 47: Schindler's List (1993), Genre: Drama, War, Rating: 5.0\nMovie 48: Beauty and the Beast (1991), Genre: Animation, Children, Fantasy, Musical, Romance, IMAX, Rating: 5.0\nMovie 49: Pulp Fiction (1994), Genre: Comedy, Crime, Drama, Thriller, Rating: 5.0\nMovie 50: Dances with Wolves (1990), Genre: Adventure, Drama, Western, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer:\n    "]

# %%
prompts_2step = []

for user_id in top_movies['userId'].unique()[:num_users]:
    prompt1 = generate_step1_prompt(top_movies, user_id)
    response1 = response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages= [{ 'role':'user','content' : prompt1}],
        max_tokens=200,
        temperature=0,
        )
    response1 = response.choices[0].message.content
    prompt2 = generate_step2_prompt(top_movies, user_id, response1)
    prompts_2step.append(prompt2)

prompts_2step
# Out:
# ["\nI am user 1. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 1: Tombstone (1993), Genre: Action, Drama, Western, Rating: 5.0\nMovie 2: Canadian Bacon (1995), Genre: Comedy, War, Rating: 5.0\nMovie 3: Pink Floyd: The Wall (1982), Genre: Drama, Musical, Rating: 5.0\nMovie 4: Messenger: The Story of Joan of Arc, The (1999), Genre: Drama, War, Rating: 5.0\nMovie 5: Good Morning, Vietnam (1987), Genre: Comedy, Drama, War, Rating: 5.0\nMovie 6: Rob Roy (1995), Genre: Action, Drama, Romance, War, Rating: 5.0\nMovie 7: Henry V (1989), Genre: Action, Drama, Romance, War, Rating: 5.0\nMovie 8: Schindler's List (1993), Genre: Drama, War, Rating: 5.0\nMovie 9: M*A*S*H (a.k.a. MASH) (1970), Genre: Comedy, Drama, War, Rating: 5.0\nMovie 10: Green Mile, The (1999), Genre: Crime, Drama, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer: Based on your top-rated movies, it seems like you enjoy a mix of genres including action, drama, war, comedy, and romance. You also seem to appreciate movies with strong storytelling and emotional depth. Additionally, historical and biographical films seem to appeal to you.\nStep 2: Please recommend 10 movies similar to these that I haven't watched yet. Format your response as a list of movie titles, using brackets around the titles and separating each title with a new line for easy parsing.\nExample format:\nHere are the 10 movies recommended for you: \n[Midnight Cowboy (1969)]\n[Lost in Translation (2003)]\n[etc.]\n\nAnswer:\n    ",
#  "\nI am user 2. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 11: Mad Max: Fury Road (2015), Genre: Action, Adventure, Sci-Fi, Thriller, Rating: 5.0\nMovie 12: Warrior (2011), Genre: Drama, Rating: 5.0\nMovie 13: Inside Job (2010), Genre: Documentary, Rating: 5.0\nMovie 14: Step Brothers (2008), Genre: Comedy, Rating: 5.0\nMovie 15: Wolf of Wall Street, The (2013), Genre: Comedy, Crime, Drama, Rating: 5.0\nMovie 16: The Jinx: The Life and Deaths of Robert Durst (2015), Genre: Documentary, Rating: 5.0\nMovie 17: Town, The (2010), Genre: Crime, Drama, Thriller, Rating: 4.5\nMovie 18: Good Will Hunting (1997), Genre: Drama, Romance, Rating: 4.5\nMovie 19: Inglourious Basterds (2009), Genre: Action, Drama, War, Rating: 4.5\nMovie 20: Dark Knight, The (2008), Genre: Action, Crime, Drama, IMAX, Rating: 4.5\nStep 1: What are my key preferences when selecting movies?\nAnswer: Based on your top-rated movies, it seems like you enjoy a variety of genres including action, drama, comedy, and documentary. You also seem to appreciate movies with high ratings and critical acclaim. Additionally, you may have a preference for intense and thrilling movies based on the genres listed.\nStep 2: Please recommend 10 movies similar to these that I haven't watched yet. Format your response as a list of movie titles, using brackets around the titles and separating each title with a new line for easy parsing.\nExample format:\nHere are the 10 movies recommended for you: \n[Midnight Cowboy (1969)]\n[Lost in Translation (2003)]\n[etc.]\n\nAnswer:\n    ",
#  "\nI am user 3. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 21: Saturn 3 (1980), Genre: Adventure, Sci-Fi, Thriller, Rating: 5.0\nMovie 22: Android (1982), Genre: Sci-Fi, Rating: 5.0\nMovie 23: Troll 2 (1990), Genre: Fantasy, Horror, Rating: 5.0\nMovie 24: The Lair of the White Worm (1988), Genre: Comedy, Horror, Rating: 5.0\nMovie 25: Hangar 18 (1980), Genre: Action, Sci-Fi, Thriller, Rating: 5.0\nMovie 26: Galaxy of Terror (Quest) (1981), Genre: Action, Horror, Mystery, Sci-Fi, Rating: 5.0\nMovie 27: Death Race 2000 (1975), Genre: Action, Sci-Fi, Rating: 5.0\nMovie 28: Alien Contamination (1980), Genre: Action, Horror, Sci-Fi, Rating: 5.0\nMovie 29: Escape from L.A. (1996), Genre: Action, Adventure, Sci-Fi, Thriller, Rating: 5.0\nMovie 30: Road Warrior, The (Mad Max 2) (1981), Genre: Action, Adventure, Sci-Fi, Thriller, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer: Based on your top-rated movies, it seems like you enjoy movies in the genres of Sci-Fi, Horror, Action, Adventure, and Thriller. You also seem to appreciate older movies from the 1970s and 1980s. Your key preferences when selecting movies appear to be a mix of science fiction, horror, and action genres with a preference for older films.\nStep 2: Please recommend 10 movies similar to these that I haven't watched yet. Format your response as a list of movie titles, using brackets around the titles and separating each title with a new line for easy parsing.\nExample format:\nHere are the 10 movies recommended for you: \n[Midnight Cowboy (1969)]\n[Lost in Translation (2003)]\n[etc.]\n\nAnswer:\n    ",
#  "\nI am user 4. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 31: L.I.E. (2001), Genre: Drama, Rating: 5.0\nMovie 32: No Man's Land (2001), Genre: Drama, War, Rating: 5.0\nMovie 33: Hairspray (1988), Genre: Comedy, Drama, Rating: 5.0\nMovie 34: Gods Must Be Crazy, The (1980), Genre: Adventure, Comedy, Rating: 5.0\nMovie 35: Monty Python's Life of Brian (1979), Genre: Comedy, Rating: 5.0\nMovie 36: Monty Python and the Holy Grail (1975), Genre: Adventure, Comedy, Fantasy, Rating: 5.0\nMovie 37: I'm the One That I Want (2000), Genre: Comedy, Rating: 5.0\nMovie 38: Traffic (2000), Genre: Crime, Drama, Thriller, Rating: 5.0\nMovie 39: Blow (2001), Genre: Crime, Drama, Rating: 5.0\nMovie 40: Philadelphia Story, The (1940), Genre: Comedy, Drama, Romance, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer: Based on your top-rated movies, it seems like you enjoy a variety of genres including drama, comedy, adventure, and crime. You also seem to appreciate movies with high ratings and critical acclaim. Additionally, you may have a preference for older classic films as some of your top-rated movies are from the 1970s and earlier.\nStep 2: Please recommend 10 movies similar to these that I haven't watched yet. Format your response as a list of movie titles, using brackets around the titles and separating each title with a new line for easy parsing.\nExample format:\nHere are the 10 movies recommended for you: \n[Midnight Cowboy (1969)]\n[Lost in Translation (2003)]\n[etc.]\n\nAnswer:\n    ",
#  "\nI am user 5. My most recent 10 top-rated movies are listed below along with their genres and ratings:\nMovie 41: Heavenly Creatures (1994), Genre: Crime, Drama, Rating: 5.0\nMovie 42: Once Were Warriors (1994), Genre: Crime, Drama, Rating: 5.0\nMovie 43: In the Name of the Father (1993), Genre: Drama, Rating: 5.0\nMovie 44: Pinocchio (1940), Genre: Animation, Children, Fantasy, Musical, Rating: 5.0\nMovie 45: Postman, The (Postino, Il) (1994), Genre: Comedy, Drama, Romance, Rating: 5.0\nMovie 46: Snow White and the Seven Dwarfs (1937), Genre: Animation, Children, Drama, Fantasy, Musical, Rating: 5.0\nMovie 47: Schindler's List (1993), Genre: Drama, War, Rating: 5.0\nMovie 48: Beauty and the Beast (1991), Genre: Animation, Children, Fantasy, Musical, Romance, IMAX, Rating: 5.0\nMovie 49: Pulp Fiction (1994), Genre: Comedy, Crime, Drama, Thriller, Rating: 5.0\nMovie 50: Dances with Wolves (1990), Genre: Adventure, Drama, Western, Rating: 5.0\nStep 1: What are my key preferences when selecting movies?\nAnswer: Based on your top-rated movies, it seems like you enjoy a variety of genres including crime, drama, animation, children, fantasy, musical, romance, comedy, war, thriller, adventure, and western. You also seem to appreciate highly acclaimed and critically acclaimed films, as many of your top-rated movies are considered classics or have received awards and recognition. Additionally, you seem to enjoy movies with strong storytelling, emotional depth, and impactful themes.\nStep 2: Please recommend 10 movies similar to these that I haven't watched yet. Format your response as a list of movie titles, using brackets around the titles and separating each title with a new line for easy parsing.\nExample format:\nHere are the 10 movies recommended for you: \n[Midnight Cowboy (1969)]\n[Lost in Translation (2003)]\n[etc.]\n\nAnswer:\n    "]

# %%
def openai_response(prompts, num_users, output_file='responses.json'):

    responses = []
    for i in range(num_users):
        response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages= [{ 'role':'user','content' : prompts[i]}],
        temperature=0,
        )
        responses.append(response)

    # parse the responses
    responses_recommendations = [extract_movie_titles(response.choices[0].message.content) for response in responses]

    # write the responses to a file
    with open(output_file, 'w') as f:
        for i in range(num_users):
            f.write(str(responses_recommendations[i]) + '\n')
        
        print(f"Response written to {output_file}")
    return responses_recommendations

# calculate the hit rate
# hit rate for the recommendations
def hit_rate(recommendation, actual):
    hit = 0
    for rec in recommendation:
        if rec in actual:
            hit += 1
    return hit/len(recommendation)

# NDCG for the recommendations
def ndcg(recommendation, actual):
    dcg = 0
    for i, rec in enumerate(recommendation):
        if rec in actual:
            dcg += 1/np.log2(i+2)
    idcg = 0
    for i in range(len(actual)):
        idcg += 1/np.log2(i+2)
    return dcg/idcg


def eval_response(responses_recommendations, selected_movie_data, original_movie_data, num_users):
    hit_rates = []
    ndcg_scores = []
    for i in range(num_users):
        user_id = selected_movie_data['userId'].unique()[i]
        user_movies = original_movie_data[original_movie_data['userId']==user_id]
        user_watched_movies = user_movies['title'].values
        # print(f"User {user_id} watched movies: {user_watched_movies}")
        recommendation = responses_recommendations[i]
        # print(f"Recommendation: {recommendation}")
        hit_rate_ = hit_rate(recommendation, user_watched_movies)
        # print(f"Hit Rate: {hit_rate_}")
        hit_rates.append(hit_rate_)
        ndcg_ = ndcg(recommendation, user_watched_movies)
        # print(f"NDCG: {ndcg_}")
        ndcg_scores.append(ndcg_)

    avg_hit_rate = np.mean(hit_rates)
    avg_ndcg = np.mean(ndcg_scores)

    print(f"Average Hit Rate: {avg_hit_rate}")
    print(f"Average NDCG: {avg_ndcg}")

    return hit_rates, ndcg_scores

# %%
# read the responses from the json file
def read_responses(output_file):
    responses_recommendations = []
    with open(output_file, 'r') as f:
        for line in f:
            responses_recommendations.append(eval(line))
    return responses_recommendations

# %%
prompt_2_step = openai_response(prompts_2step, num_users, 'responses_2step.json')

hit_rates_2, ndcg_scores_2 = eval_response(prompt_2_step, top_movies, movie_latest_small, num_users)
# Out:
# Response written to responses_2step.json
# Average Hit Rate: 0.21999999999999997
# Average NDCG: 0.052519115042399055
